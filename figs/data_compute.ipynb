# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 22
#      19 df = df[df["family"].isin(["gpt", "llama", "palm", "claude", "bert", "t5"])]
#      21 # Create scatter plot
# ---> 22 fig = px.scatter(
#      23     df,
#      24     x="year",
#      25     y="compute_log",
#      26     size="Training dataset size (datapoints)",
#      27     color="family",
#      28     hover_data=["Model"],
#      29     labels={
#      30         "compute_log": "Compute (log10 FLOP)",
#      31         "year": "Year",
#      32         "family": "Model Family",
#      33     },
#      34     title="AI Models: Compute vs Year",
#      35 )
#      37 fig.update_layout(height=800, template="plotly_white")
#      39 fig.show()
#
# ...
